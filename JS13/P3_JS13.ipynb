# %% [markdown]
# Nama : Aditya Atadewa
# Kelas : TI 3G
# NIM : 2341720174
# Absen : 01

# %% [markdown]
# # Praktikum 3
#
# Praktikum 3 kali ini kita akan mencoba menggunakan Keras untuk Regresi, khususnya pada kasus Prediksi Harga Rumah.

# %% [markdown]
# ## Praktikum Menggunakan Dummy Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=100)

# Evaluasi
print("Prediksi:", model.predict(X_test))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 2.6426
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 2.6244
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 2.6064
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2.5884
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 2.5706
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 2.5529
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 2.5353
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.5179
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.5005
# Epoch 10/100
# ...

# %% [markdown]
# ## Tugas 4
#
# - Ubah learning rate.
# - Bandingkan hasil loss.

# %% [markdown]
# ### Learning Rate Besar (0.01)

# %%
# Tugas 4 - Learning Rate 0.01

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Dataset dummy
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X = scaler_X.fit_transform(X)
y = scaler_y.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model dengan LR lebih besar (0.01)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='mse')

# Training
history_lr_high = model.fit(X_train, y_train, epochs=100, verbose=1)

print("Loss akhir (LR 0.01):", history_lr_high.history['loss'][-1])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step - loss: 1.3254
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.2260
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.1299
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.0373
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.9482
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.8630
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.7853
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7108
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.6396
# Epoch 10/100
# ...

# %% [markdown]
# ### Learning Rate Kecil (0.0001)

# %%
# Tugas 4 - Learning Rate 0.0001

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Dataset dummy
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X = scaler_X.fit_transform(X)
y = scaler_y.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model dengan LR kecil (0.0001)
model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

optimizer2 = tf.keras.optimizers.Adam(learning_rate=0.0001)
model2.compile(optimizer=optimizer2, loss='mse')

# Training
history_lr_low = model2.fit(X_train, y_train, epochs=100, verbose=1)

print("Loss akhir (LR 0.0001):", history_lr_low.history['loss'][-1])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step - loss: 0.5530
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5523
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5516
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5509
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5502
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5494
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5487
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5480
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5473
# Epoch 10/100
# ...

# %% [markdown]
# ### **Deskripsi Tugas**
#
# Pada Tugas 4, model ANN regresi dilatih menggunakan dua nilai **learning rate** berbeda untuk melihat pengaruhnya terhadap hasil *loss*.
# Learning rate yang diuji:
#
# - **0.01 (lebih besar dari default)**
# - **0.0001 (lebih kecil dari default)**
#
# ---
#
# ### **Hasil Loss Akhir**
#
# | Learning Rate | Loss Akhir | Keterangan |
# |---------------|------------|------------|
# | **0.01** | **0.002429** | Loss sangat kecil, training cepat konvergen |
# | **0.0001** | **0.483783** | Loss besar, training lambat belajar |
#
# ---
#
# ### **Analisis**
#
# **1. Learning Rate Besar (0.01)**
# - Loss akhir: **0.0024**
# - Nilai sangat sangat kecil → model cepat mencapai titik optimal.
# - Learning rate besar membuat langkah update bobot lebih agresif sehingga konvergensi lebih cepat.
# - Pada dataset kecil (dummy data sederhana), learning rate besar **bekerja sangat baik**.
#
# **2. Learning Rate Kecil (0.0001)**
# - Loss akhir: **0.4837** (jauh lebih tinggi)
# - Model belajar sangat lambat.
# - Karena langkah update bobot kecil sekali, diperlukan lebih banyak epoch agar loss turun.
# - Dengan hanya 100 epoch, model belum sempat mendekati optimal.
#
# ---
#
# # **Kesimpulan**
#
# - Learning rate memiliki pengaruh besar terhadap performa training model regresi.
# - Pada dataset dummy, learning rate **lebih besar (0.01)** memberikan hasil jauh lebih baik (loss sangat kecil), sedangkan learning rate **sangat kecil (0.0001)** membuat training lambat sehingga loss tetap tinggi meskipun model telah dilatih selama 100 epoch.

# %% [markdown]
# ## Praktikum Menggunakan Boston Dataset (MLP Regresi)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# 1. Load
data = fetch_california_housing()
X, y = data.data, data.target

# 2. Preprocess
scaler = StandardScaler()
Xs = scaler.fit_transform(X)
X_train, X_val, y_train, y_val = train_test_split(Xs, y, test_size=0.2, random_state=42)

# 3. Build model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])
model.compile(optimizer=Adam(1e-3), loss='mse', metrics=['mae'])

# 4. Train
h = model.fit(X_train, y_train, validation_data=(X_val, y_val),
              epochs=200, batch_size=32, verbose=0)

# 5. Plot
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(h.history['loss'], label='train_loss')
plt.plot(h.history['val_loss'], label='val_loss')
plt.legend(); plt.title('MSE')

plt.subplot(1,2,2)
plt.plot(h.history['mae'], label='train_mae')
plt.plot(h.history['val_mae'], label='val_mae')
plt.legend(); plt.title('MAE')

plt.show()

# 6. Evaluate
pred = model.predict(X_val)
print('RMSE:', np.sqrt(mean_squared_error(y_val, pred)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RMSE: 0.5110854593983016
